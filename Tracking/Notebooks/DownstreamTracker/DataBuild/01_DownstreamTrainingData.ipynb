# %%
import sys
sys.path.append('/home/hashmi/ResearchBook/Tracking/Notebooks')
from central_import import *

figure_directory = '../../Figures/Databuild/'
os.makedirs(figure_directory,exist_ok=True)
set_plot_style()

# %%
#Calling the input file
keys=['p','pt','px','py','pz','ovtx_x','ovtx_y','eta','phi','nUTHits','chi2','ndof','isMatched']
data = uproot.open('../../../Data/TrackDumper/Downstream/Dumper_recTracks.root:Hits_detectors').arrays(keys,library='pd')

# %%
data
# Out:
#                   p           pt           px           py            pz  \
# 0       5909.817556   428.277705  -408.473668   128.728613   5894.278730
# 1       5538.734420   282.645307  -233.720748   158.943329   5531.517929
# 2      11578.541378   630.442231  -629.928178    25.453822  11561.365103
# 3      15305.070720   833.397923  -666.631128   500.155013  15282.363614
# 4       7032.182276   123.075688   -67.120282   103.162457   7031.105172
# ...             ...          ...          ...          ...           ...
# 55497   6266.402057  1371.348773  1346.058683  -262.151630   6114.507117
# 55498   3167.743274   135.182565    96.731793   -94.431384   3164.857521
# 55499   8675.961084  1258.596042   -19.218366 -1258.449304   8584.185269
# 55500   6439.128153   948.986185   101.398110  -943.553497   6368.814379
# 55501  13259.032420  2554.655020  2327.445512 -1053.213967  13010.598697
#
#            ovtx_x      ovtx_y       eta       phi  nUTHits      chi2  ndof  \
# 0     -154.245087   51.721882  3.316430  2.836300        4  3.530421    12
# 1      -89.850204   68.142715  3.667824  2.544377        4  1.383085    12
# 2     -123.821136    4.228925  3.602892  3.101207        4  2.131646    11
# 3      -97.630684   76.527649  3.602833  2.497917        4  2.169970    11
# 4      -14.400462   33.429001  4.738523  2.147612        4  2.621901    12
# ...           ...         ...       ...       ...      ...       ...   ...
# 55497  500.861053  -97.925133  2.200361 -0.192347        3  2.811464    12
# 55498   86.621300  -76.440697  3.846840 -0.773365        4  6.098898    12
# 55499    0.308581 -343.766754  2.618403 -1.586067        6  3.523841    12
# 55500   32.055061 -350.213837  2.602427 -1.463743        4  6.342439    12
# 55501  428.050110 -188.949768  2.330496 -0.424947        4  8.235586    11
#
#        isMatched
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# ...          ...
# 55497       True
# 55498       True
# 55499       True
# 55500       True
# 55501       True
#
# [55502 rows x 13 columns]

# %%
random_indices = np.random.choice(data.shape[0], 500, replace=False)


# Scatter plot for the selected random hits
sns.scatterplot(x=data['px'].iloc[random_indices], y=data['py'].iloc[random_indices], 
                s=25, edgecolor='black', alpha=0.7)

# Labels and title
plt.xlabel('Px [GeV]')
plt.ylabel('Py [GeV]')
plt.title("Momentum Distribution in Px-Py Plane for Selected Hits")

# Set limits and grid
plt.xlim(-4000, 4000)
plt.ylim(-6000, 6000)

plt.savefig("{}/DownstreamPxPy.png".format(figure_directory))
plt.show()

# %%
data['tx'] = data['px'] / data['pz']
data['ty'] = data['py'] / data['pz']
data['chi2perdof'] = data['chi2'] / data['ndof']


model_data = data[['p','pt','tx','ty','ovtx_x','ovtx_y','eta','phi','nUTHits','chi2perdof','isMatched']]

# %%
model_data.head()
# Out:
#               p          pt        tx        ty      ovtx_x     ovtx_y  \
# 0   5909.817556  428.277705 -0.069300  0.021840 -154.245087  51.721882
# 1   5538.734420  282.645307 -0.042253  0.028734  -89.850204  68.142715
# 2  11578.541378  630.442231 -0.054486  0.002202 -123.821136   4.228925
# 3  15305.070720  833.397923 -0.043621  0.032728  -97.630684  76.527649
# 4   7032.182276  123.075688 -0.009546  0.014672  -14.400462  33.429001
#
#         eta       phi  nUTHits  chi2perdof  isMatched
# 0  3.316430  2.836300        4    0.294202       True
# 1  3.667824  2.544377        4    0.115257       True
# 2  3.602892  3.101207        4    0.193786       True
# 3  3.602833  2.497917        4    0.197270       True
# 4  4.738523  2.147612        4    0.218492       True

# %%
model_data.to_parquet('DownstreamTrackTrainingData.parquet')
