# %%
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd
import os

from DashboardPlots import dashboard


sns.set_theme('notebook')


file_lists = os.listdir('./Outputs/')

# %%
for file_name in file_lists:

    dashboard(file_name)

    # break

# %%
# plt.figure(figsize=(16,8))
# staves_file = pd.read_csv(f'./Outputs/[293528, 293530, 293532, 293533, 297288, 298593, 298594, 298595, 298596, 302935]/staves_prediction.csv')

# staves_file['Module'] = staves_file['Staves'].str.cat(staves_file['Rows'],sep=',')

# sns.lineplot(data = staves_file,x = 'Module', y='TrueValues',label='True Value')
# sns.lineplot(data = staves_file,x = 'Module', y='Predictions',label='Predictions')

# plt.ylim(0, 1)

# plt.xticks(ticks=staves_file.index[::5], rotation=90,fontsize=8)
# plt.show()
